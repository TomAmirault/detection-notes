# %%
from whisper_transcribe import transcribe_audio
import warnings
warnings.filterwarnings("ignore")

# %%
file_path = "audio.mp3"
transcribe_audio(file_path, model_size="tiny")
# Out:
# c:\DTY\RTE\detection-notes\.venv\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# " Et pylogue, la piratrice sur la ligne de France, chacune des deux visions de la culture et de la connaissance qui s'affronte aujourd'hui. Cinquered autour d'une figure mythique qui définit le regard porté par la société sur le créateur. Ces deux modes, influence les évolutions du droit qui en se rupture et en organisé les règles. Le modèle du génie romantique a caparé par les marchands du savoir, pour s'adésormais un durcissement continu de la propriété intellectuelle. Chacocopieur, extension du champ du privatisable, guerre au public. Fas à cette expansion promue par les gouvernements depuis une vingtaine d'années, le camp des accords a amenagé un espace d'ouverture, démontrant ainsi la force de son modèle et permettant d'en révaluer d'autres, comme celui de la science ouverte. Mais les deux modèles ne sont pas étangues. Et il se rénaif d'imaginer une coexistence à peser. Les défenseurs du génie romantique a s'y égée ce défend avec vigueur, leur usage obsessionnel du mot piratri, aujourd'hui en élus signe le plus évident. L'ontant qu'entonner au domaine de la copie illicitte à visé commercial, il sert désormais à affectiver le public investit dans des pratiques des changements marchandes. Le préambi-bio-tech a été qualifié de contrefassons. Le téléchargement de musique sur les services de Pierre Tupier et des Nancés en bloc, comme un vol à leur même qui s'y recue leci désœuvre en Libraxé. Ce glissement de sens est politique. Le mot pirat, mais elle, les mafias et le public, éjetent le probe sur les créateurs pratiquant le partage. C'est donc, sur le terrain économique et politique que l'écure doit désormais porter leur attention. Car?"

# %%
import sounddevice as sd
import soundfile as sf
import whisper
import time
import os


def transcribe_audio(file_path, model_size="tiny"):
    model = whisper.load_model(model_size)
    result = model.transcribe(file_path)
    return result["text"]


def record_and_transcribe_loop(duration=10, samplerate=16000, model_size="tiny"):
    model = whisper.load_model(model_size)  # Charger le modèle une seule fois

    try:
        counter = 1
        while True:
            filename = f"record_chunk_{counter}.wav"
            if counter == 1 :
                print(f"Parlez maintenant")
            recording = sd.rec(int(duration * samplerate), samplerate=samplerate, channels=1, dtype="float32")
            sd.wait()

            sf.write(filename, recording, samplerate)

            # Transcrire avec le modèle déjà chargé
            result = model.transcribe(filename, initial_prompt=)
            print(f"Transcription [{counter}] :", result["text"], "\n")

            counter += 1

    except KeyboardInterrupt:
        print("\n Arrêt demandé par l'utilisateur (Ctrl+C).")


if __name__ == "__main__":
    record_and_transcribe_loop(duration=10, model_size="tiny")
# Out:
# Parlez maintenant
# Transcription [1] :
#
#
#  Arrêt demandé par l'utilisateur (Ctrl+C).
